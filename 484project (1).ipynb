# %%
import pandas as pd
import io

# %%
f = 'questions.csv'
df = pd.read_csv(f)

# %% [markdown]
# f_backup = df

# %%
temp_df = df_backup

# %%
temp_df = df.head(10000)

# %%
# !pip install texthero
import texthero as hero

# %%
merged_question = []

# %%
for i in range(len(temp_df)):
  merged_question.append(temp_df['question1'][i])

# %%
for i in range(len(temp_df)):
  merged_question.append(temp_df['question2'][i])

# %%
new_df = pd.DataFrame(merged_question, columns =['all_questions'])

# %%
new_df['tfidf'] = (
  new_df['all_questions']
  .pipe(hero.clean)
   .pipe(hero.tfidf)
)

# %%
new_df

# %%
import scipy.spatial.distance as distancepack

# %%
correct = 0
incorrect = 0

# %%
for i in range(len(temp_df)):
  dist = distancepack.cosine(new_df['tfidf'][i], new_df['tfidf'][i+len(temp_df)])
  similarity = 1-dist
  threshold = 0.3

# %%
  if similarity >= threshold and df['is_duplicate'][i] == 1:
    correct += 1

# %%
  if similarity >= threshold and df['is_duplicate'][i] == 0:
    incorrect += 1

# %%
  if similarity < threshold and df['is_duplicate'][i] == 1:
    incorrect += 1

# %%
  if similarity < threshold and df['is_duplicate'][i] == 0:
    incorrect += 1

# %% [markdown]
#  print(similarity, df['is_duplicate'][i])

# %%
print('correct', correct)
print('incorrect', incorrect)
